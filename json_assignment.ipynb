# %% [markdown]
# <a href="https://colab.research.google.com/github/gbhav1003/fittrack-project-26011078/blob/main/json_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1 — Build a JSON Structure

# %%
import json

user_profile = {
    "name": "Arjun",
    "age": 28,
    "email": "arjun@example.com",
    "is_active": True,
    "skills": ["Python", "Data Analysis", "Machine Learning"]
}

json_string = json.dumps(user_profile, indent=4)
print(json_string)
# Out:
# {
#     "name": "Arjun",
#     "age": 28,
#     "email": "arjun@example.com",
#     "is_active": true,
#     "skills": [
#         "Python",
#         "Data Analysis",
#         "Machine Learning"
#     ]
# }

# %% [markdown]
# Task 2 — Parse an API Response

# %%
import json

api_response = '{"status": "success", "data": {"user_id": 101, "username": "alex99", "score": 87.5}}'
parsed_data = json.loads(api_response)
print(parsed_data)

username = parsed_data["data"]["username"]
score = parsed_data["data"]["score"]

print(f"Username: {username}")
print(f"Score: {score}")
print(f"User {username} scored {score} points")
# Out:
# {'status': 'success', 'data': {'user_id': 101, 'username': 'alex99', 'score': 87.5}}
# Username: alex99
# Score: 87.5
# User alex99 scored 87.5 points

# %% [markdown]
# Task 3 — Handle Nested JSON

# %%
user_json = '''
{
  "name": "Priya",
  "address": {
    "city": "Bengaluru",
    "state": "Karnataka",
    "zip": "560001"
  }
}
'''
data = json.loads(user_json)

# Extract and print city and zip
print(f"City: {data['address']['city']}")
print(f"Zip Code: {data['address']['zip']}")

# Update dictionary and print
data["address"]["country"] = "India"
print(json.dumps(data, indent=2))
# Out:
# City: Bengaluru
# Zip Code: 560001
# {
#   "name": "Priya",
#   "address": {
#     "city": "Bengaluru",
#     "state": "Karnataka",
#     "zip": "560001",
#     "country": "India"
#   }
# }
